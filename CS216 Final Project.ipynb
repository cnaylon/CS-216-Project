# %%
import numpy as np
import pandas as pd
import warnings
import re
warnings.filterwarnings('ignore')
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
import matplotlib.pyplot as plt

# %%
passing_1985 = pd.read_csv("NFL_passing_1985.csv")
passing_1985_qb = passing_1985[(passing_1985['Pos'] == "QB") | (passing_1985['Pos'] == "qb")]
passing_1985_qb['Player'] = passing_1985_qb['Player'].str.replace('[+$]+', '')
passing_1985_qb['Player'] = passing_1985_qb['Player'].str.replace('[*$]+', '')
passing_1985_qb = passing_1985_qb[passing_1985_qb['GS'] >= 8]
print(len(passing_1985_qb))
passing_1985_qb.head()
# Out:
# 28
#    Rk       Player   Tm  Age Pos   G  GS    QBrec  Cmp  Att  ...   Y/C    Y/G  \
# 0   1   Dan Marino  MIA   24  QB  16  16  12/4/00  336  567  ...  12.3  258.6
# 1   2   John Elway  DEN   25  QB  16  16  11/5/00  327  605  ...  11.9  243.2
# 2   3  Ken O'Brien  NYJ   25  QB  16  16  11/5/00  297  488  ...  13.1  243.0
# 3   4   Phil Simms  NYG   30  QB  16  16  10/6/00  275  495  ...  13.9  239.3
# 4   5  Joe Montana  SFO   29  QB  15  15   9/6/00  303  494  ...  12.1  243.5
#
#    Rate  Sk  Yds.1   Sk%  NY/A  ANY/A  4QC  GWD
# 0  84.1  18    157   3.1  6.80   6.21  3.0  5.0
# 1  70.2  38    307   5.9  5.57   4.65  6.0  6.0
# 2  96.2  62    399  11.3  6.34   6.60  1.0  1.0
# 3  78.6  52    396   9.5  6.28   5.44  0.0  0.0
# 4  91.3  35    246   6.6  6.44   6.36  1.0  1.0
#
# [5 rows x 29 columns]

# %%
rushing_1985 = pd.read_csv("NFL_rushing_1985.csv")
rushing_1985_qb = rushing_1985[(rushing_1985['Pos'] == "QB") | (rushing_1985['Pos'] == "qb")]
rushing_1985_qb['Player'] = rushing_1985_qb['Player'].str.replace('[+$]+', '')
rushing_1985_qb['Player'] = rushing_1985_qb['Player'].str.replace('[*$]+', '')
rushing_1985_qb = rushing_1985_qb[rushing_1985_qb['GS'] >= 8]
rushing_1985_qb["Year"] = 1985
print(len(rushing_1985_qb))
rushing_1985_qb.head()
# Out:
# 28
#     Rk        Player   Tm  Age Pos   G  GS  Att  Yds  TD  Lng  Y/A   Y/G  Fmb  \
# 59  60  David Archer  ATL   23  QB  16  11   70  347   2   29  5.0  21.7    9
# 69  70    John Elway  DEN   25  QB  16  16   51  253   0   22  5.0  15.8    7
# 73  74   Jim McMahon  CHI   26  QB  13  11   47  252   3   19  5.4  19.4    4
# 79  80   Joe Montana  SFO   29  QB  15  15   42  153   3   16  3.6  10.2    5
# 83  84   Warren Moon  HOU   29  QB  14  14   39  130   0   17  3.3   9.3   12
#
#     Year
# 59  1985
# 69  1985
# 73  1985
# 79  1985
# 83  1985

# %%
passing_2021 = pd.read_csv("NFL_passing_2021.csv")
passing_2021_qb = passing_2021[(passing_2021['Pos'] == "QB") | (passing_2021['Pos'] == "qb")]
passing_2021_qb['Player'] = passing_2021_qb['Player'].str.replace('[+$]+', '')
passing_2021_qb['Player'] = passing_2021_qb['Player'].str.replace('[*$]+', '')
passing_2021_qb = passing_2021_qb[passing_2021_qb['GS'] >= 8]
print(len(passing_2021_qb))
passing_2021_qb.head()
# Out:
# 32
#    Rk            Player   Tm  Age Pos   G  GS    QBrec  Cmp  Att  ...    Y/G  \
# 0   1         Tom Brady  TAM   44  QB  17  17   13-4-0  485  719  ...  312.7
# 1   2    Justin Herbert  LAC   23  QB  17  17   9/8/00  443  672  ...  294.9
# 2   3  Matthew Stafford  LAR   33  QB  17  17  12/5/00  404  601  ...  287.4
# 3   4   Patrick Mahomes  KAN   26  QB  17  17  12/5/00  436  658  ...  284.6
# 4   5        Derek Carr  LVR   30  QB  17  17  10/7/00  428  626  ...  282.6
#
#     Rate   QBR  Sk  Yds.1  Sk%  NY/A  ANY/A  4QC  GWD
# 0  102.1  68.1  22    144  3.0  6.98   7.41  3.0  5.0
# 1   97.7  65.6  31    214  4.4  6.83   6.95  5.0  5.0
# 2  102.9  63.8  30    243  4.8  7.36   7.45  3.0  4.0
# 3   98.5  62.2  28    146  4.1  6.84   7.07  3.0  3.0
# 4   94.0  52.4  40    241  6.0  6.85   6.60  3.0  6.0
#
# [5 rows x 31 columns]

# %%
rushing_2021 = pd.read_csv("NFL_rushing_2021.csv")
rushing_2021_qb = rushing_2021[(rushing_2021['Pos'] == "QB") | (rushing_2021['Pos'] == "qb")]
rushing_2021_qb['Player'] = rushing_2021_qb['Player'].str.replace('[+$]+', '')
rushing_2021_qb['Player'] = rushing_2021_qb['Player'].str.replace('[*$]+', '')
rushing_2021_qb = rushing_2021_qb[rushing_2021_qb['GS'] >= 8]
print(len(rushing_2021_qb))
rushing_2021_qb.head()
# Out:
# 32
#     Rk           Player   Tm  Age Pos   G  GS  Att  Yds  TD  1D  Lng  Y/A  \
# 34  35      Jalen Hurts  PHI   23  QB  15  15  139  784  10  56   31  5.6
# 40  41    Lamar Jackson  BAL   24  QB  12  12  133  767   2  48   31  5.8
# 43  44       Josh Allen  BUF   25  QB  17  17  122  763   6  54   34  6.3
# 56  57     Kyler Murray  ARI   24  QB  14  14   88  423   5  25   57  4.8
# 62  63  Trevor Lawrence  JAX   22  QB  17  17   73  334   2  22   26  4.6
#
#      Y/G  Fmb
# 34  52.3    9
# 40  63.9    6
# 43  44.9    8
# 56  30.2   13
# 62  19.6    9

# %%
# Merge 1985 datasets
qb_1985 = pd.merge(passing_1985_qb, rushing_1985_qb, on = "Player")
qb_1985[['Wins', 'Losses', 'Ties']] = qb_1985['QBrec'].str.split('[/|-]', expand=True)
qb_1985 = qb_1985.drop(columns = ["Rk_x", "Rk_y", "Pos_y", "G_y", "GS_y", "Age_y", "Tm_y", "QBrec"])
qb_1985["Year"] = 1985
qb_1985['Winpct'] = (qb_1985['Wins'].astype(int) + 0.5*(qb_1985['Ties'].astype(int))) / qb_1985['GS_x'].astype(int)
qb_1985 = qb_1985.dropna()
print(len(qb_1985))
qb_1985.head()
# Out:
# 20
#         Player Tm_x  Age_x Pos_x  G_x  GS_x  Cmp  Att_x  Cmp%  Yds_x  ...  \
# 0   Dan Marino  MIA     24    QB   16    16  336    567  59.3   4137  ...
# 1   John Elway  DEN     25    QB   16    16  327    605  54.0   3891  ...
# 2  Ken O'Brien  NYJ     25    QB   16    16  297    488  60.9   3888  ...
# 3   Phil Simms  NYG     30    QB   16    16  275    495  55.6   3829  ...
# 4  Joe Montana  SFO     29    QB   15    15  303    494  61.3   3653  ...
#
#    TD_y  Lng_y  Y/A_y  Y/G_y  Fmb  Year  Wins  Losses  Ties  Winpct
# 0     0      6   -0.9   -1.5    9  1985    12       4    00  0.7500
# 1     0     22    5.0   15.8    7  1985    11       5    00  0.6875
# 2     0     22    2.3    3.6   14  1985    11       5    00  0.6875
# 3     0     28    3.6    8.3   16  1985    10       6    00  0.6250
# 4     3     16    3.6   10.2    5  1985     9       6    00  0.6000
#
# [5 rows x 39 columns]

# %%
# Merge 2021 datasets
qb_2021 = pd.merge(passing_2021_qb, rushing_2021_qb, on = "Player")
qb_2021[['Wins', 'Losses', 'Ties']] = qb_2021['QBrec'].str.split('[/|-]', expand=True)
qb_2021 = qb_2021.drop(columns = ["Rk_x", "Rk_y", "Pos_y", "G_y", "GS_y", "Age_y", "Tm_y", "QBrec"])
qb_2021["Year"] = 2021
qb_2021['Winpct'] = (qb_2021['Wins'].astype(int) + 0.5*(qb_2021['Ties'].astype(int))) / qb_2021['GS_x'].astype(int)
qb_2021 = qb_2021.dropna()
print(len(qb_2021))
qb_2021.head()
# Out:
# 25
#              Player Tm_x  Age_x Pos_x  G_x  GS_x  Cmp  Att_x  Cmp%  Yds_x  \
# 0         Tom Brady  TAM     44    QB   17    17  485    719  67.5   5316
# 1    Justin Herbert  LAC     23    QB   17    17  443    672  65.9   5014
# 2  Matthew Stafford  LAR     33    QB   17    17  404    601  67.2   4886
# 3   Patrick Mahomes  KAN     26    QB   17    17  436    658  66.3   4839
# 4        Derek Carr  LVR     30    QB   17    17  428    626  68.4   4804
#
#    ...  1D_y  Lng_y  Y/A_y  Y/G_y  Fmb  Wins  Losses  Ties  Year    Winpct
# 0  ...    14     13    2.9    4.8    4    13       4     0  2021  0.764706
# 1  ...    28     36    4.8   17.8    1     9       8    00  2021  0.529412
# 2  ...     8     12    1.3    2.5    5    12       5    00  2021  0.705882
# 3  ...    25     32    5.8   22.4    9    12       5    00  2021  0.705882
# 4  ...     9     22    2.7    6.4   13    10       7    00  2021  0.588235
#
# [5 rows x 42 columns]

# %%
sns.displot(data=qb_1985, x="Winpct", bins = 10).set(title='The median QB win percentage in 1985 is around 0.5')
sns.displot(data=qb_2021, x="Winpct", bins = 10).set(title='The median QB win percentage in 2021 is slightly higher, close to 0.6')

# %%
qb_all = pd.concat([qb_2021, qb_1985])
sns.scatterplot(data = qb_all, x = "Y/G_y", y = "Winpct", hue = "Year").set(title='Mobile QBs do not necessarily produce more wins')
# Out:
# [Text(0.5, 1.0, 'Mobile QBs do not necessarily produce more wins')]

# %%
sns.scatterplot(data = qb_all, x = "Y/G_x", y = "Winpct", hue = "Year").set(title='QBs with more passing yards tend to win more games')
# Out:
# [Text(0.5, 1.0, 'QBs with more passing yards tend to win more games')]

# %%
print(qb_1985.columns.tolist())
print(qb_2021.columns.tolist())
# Out:
# ['Player', 'Tm_x', 'Age_x', 'Pos_x', 'G_x', 'GS_x', 'Cmp', 'Att_x', 'Cmp%', 'Yds_x', 'TD_x', 'TD%', 'Int', 'Int%', 'Lng_x', 'Y/A_x', 'AY/A', 'Y/C', 'Y/G_x', 'Rate', 'Sk', 'Yds.1', 'Sk%', 'NY/A', 'ANY/A', '4QC', 'GWD', 'Att_y', 'Yds_y', 'TD_y', 'Lng_y', 'Y/A_y', 'Y/G_y', 'Fmb', 'Year', 'Wins', 'Losses', 'Ties', 'Winpct']
# ['Player', 'Tm_x', 'Age_x', 'Pos_x', 'G_x', 'GS_x', 'Cmp', 'Att_x', 'Cmp%', 'Yds_x', 'TD_x', 'TD%', 'Int', 'Int%', '1D_x', 'Lng_x', 'Y/A_x', 'AY/A', 'Y/C', 'Y/G_x', 'Rate', 'QBR', 'Sk', 'Yds.1', 'Sk%', 'NY/A', 'ANY/A', '4QC', 'GWD', 'Att_y', 'Yds_y', 'TD_y', '1D_y', 'Lng_y', 'Y/A_y', 'Y/G_y', 'Fmb', 'Wins', 'Losses', 'Ties', 'Year', 'Winpct']

# %%
# 1985 passing model
lm_1985_passing = LinearRegression()
y_1 = qb_1985['Winpct']
x_1 = qb_1985[['Age_x', 'Cmp', 'Att_x', 'Yds_x', 'TD_x', 'Int', 'Lng_x', 'Rate', 'Sk']]
lm_1985_passing.fit(X = x_1, y = y_1)
qb_1985["predicted_Winpct_passing"] = lm_1985_passing.predict(x_1)
coefficents_1985_passing = pd.DataFrame(zip(x_1.columns, lm_1985_passing.coef_))
print(coefficents_1985_passing)
# Out:
#        0         1
# 0  Age_x -0.006591
# 1    Cmp -0.002379
# 2  Att_x  0.003676
# 3  Yds_x -0.000410
# 4   TD_x -0.031052
# 5    Int  0.044741
# 6  Lng_x  0.000640
# 7   Rate  0.042308
# 8     Sk -0.003122

# %%
# 1985 rushing model
lm_1985_rushing = LinearRegression()
y_2 = qb_1985['Winpct']
x_2 = qb_1985[['Age_x', 'Att_y', 'Yds_y', 'TD_y', 'Lng_y', 'Fmb']]
lm_1985_rushing.fit(X = x_2, y = y_2)
qb_1985["predicted_Winpct_rushing"] = lm_1985_rushing.predict(x_2)
coefficents_1985_rushing = pd.DataFrame(zip(x_2.columns, lm_1985_rushing.coef_))
print(coefficents_1985_rushing)
# Out:
#        0         1
# 0  Age_x  0.006234
# 1  Att_y  0.000286
# 2  Yds_y  0.000756
# 3   TD_y  0.046077
# 4  Lng_y -0.006878
# 5    Fmb -0.001683

# %%
# 2021 passing model
lm_2021_passing = LinearRegression()
y_3 = qb_2021['Winpct']
x_3 = qb_2021[['Age_x', 'Cmp', 'Att_x', 'Yds_x', 'TD_x', 'Int', 'Lng_x', 'Rate', 'Sk']]
lm_2021_passing.fit(X = x_3, y = y_3)
qb_2021["predicted_Winpct_passing"] = lm_2021_passing.predict(x_3)
coefficents_2021_passing = pd.DataFrame(zip(x_3.columns, lm_2021_passing.coef_))
print(coefficents_2021_passing)
# Out:
#        0         1
# 0  Age_x  0.006763
# 1    Cmp  0.006878
# 2  Att_x -0.005577
# 3  Yds_x  0.000061
# 4   TD_x  0.014428
# 5    Int  0.002888
# 6  Lng_x  0.001776
# 7   Rate -0.011072
# 8     Sk -0.002583

# %%
# 2021 rushing model
lm_2021_rushing = LinearRegression()
y_4 = qb_2021['Winpct']
x_4 = qb_2021[['Age_x', 'Att_y', 'Yds_y', 'TD_y', 'Lng_y', 'Fmb']]
lm_2021_rushing.fit(X = x_4, y = y_4)
qb_2021["predicted_Winpct_rushing"] = lm_2021_rushing.predict(x_4)
coefficents_2021_rushing = pd.DataFrame(zip(x_4.columns, lm_2021_rushing.coef_))
print(coefficents_2021_rushing)
# Out:
#        0         1
# 0  Age_x  0.013658
# 1  Att_y  0.008134
# 2  Yds_y -0.001094
# 3   TD_y  0.010259
# 4  Lng_y -0.000379
# 5    Fmb -0.005211

# %%
qb_1985.head()
# Out:
#         Player Tm_x  Age_x Pos_x  G_x  GS_x  Cmp  Att_x  Cmp%  Yds_x  ...  \
# 0   Dan Marino  MIA     24    QB   16    16  336    567  59.3   4137  ...
# 1   John Elway  DEN     25    QB   16    16  327    605  54.0   3891  ...
# 2  Ken O'Brien  NYJ     25    QB   16    16  297    488  60.9   3888  ...
# 3   Phil Simms  NYG     30    QB   16    16  275    495  55.6   3829  ...
# 4  Joe Montana  SFO     29    QB   15    15  303    494  61.3   3653  ...
#
#    Y/A_y  Y/G_y  Fmb  Year  Wins  Losses  Ties  Winpct  \
# 0   -0.9   -1.5    9  1985    12       4    00  0.7500
# 1    5.0   15.8    7  1985    11       5    00  0.6875
# 2    2.3    3.6   14  1985    11       5    00  0.6875
# 3    3.6    8.3   16  1985    10       6    00  0.6250
# 4    3.6   10.2    5  1985     9       6    00  0.6000
#
#    predicted_Winpct_passing  predicted_Winpct_rushing
# 0                  0.678557                  0.493576
# 1                  0.616079                  0.609784
# 2                  0.539265                  0.443082
# 3                  0.508547                  0.489017
# 4                  0.640811                  0.739376
#
# [5 rows x 41 columns]

# %%
qb_2021.head()
# Out:
#              Player Tm_x  Age_x Pos_x  G_x  GS_x  Cmp  Att_x  Cmp%  Yds_x  \
# 0         Tom Brady  TAM     44    QB   17    17  485    719  67.5   5316
# 1    Justin Herbert  LAC     23    QB   17    17  443    672  65.9   5014
# 2  Matthew Stafford  LAR     33    QB   17    17  404    601  67.2   4886
# 3   Patrick Mahomes  KAN     26    QB   17    17  436    658  66.3   4839
# 4        Derek Carr  LVR     30    QB   17    17  428    626  68.4   4804
#
#    ...  Y/A_y  Y/G_y  Fmb  Wins  Losses  Ties  Year    Winpct  \
# 0  ...    2.9    4.8    4    13       4     0  2021  0.764706
# 1  ...    4.8   17.8    1     9       8    00  2021  0.529412
# 2  ...    1.3    2.5    5    12       5    00  2021  0.705882
# 3  ...    5.8   22.4    9    12       5    00  2021  0.705882
# 4  ...    2.7    6.4   13    10       7    00  2021  0.588235
#
#    predicted_Winpct_passing  predicted_Winpct_rushing
# 0                  0.793262                  0.731107
# 1                  0.585760                  0.504459
# 2                  0.779764                  0.629611
# 3                  0.609282                  0.433010
# 4                  0.552480                  0.537142
#
# [5 rows x 44 columns]

# %%
# 1985 passing MSE and R2
mse_1985_passing = mean_squared_error(qb_1985["Winpct"].values, qb_1985["predicted_Winpct_passing"].values)
r2_1985_passing = r2_score(qb_1985["Winpct"].values, qb_1985["predicted_Winpct_passing"].values)
print("-----1985 Passing-----")
print(mse_1985_passing)
print(r2_1985_passing)

# 1985 rushing MSE and R2
mse_1985_rushing = mean_squared_error(qb_1985["Winpct"].values, qb_1985["predicted_Winpct_rushing"].values)
r2_1985_rushing = r2_score(qb_1985["Winpct"].values, qb_1985["predicted_Winpct_rushing"].values)
print("-----1985 Rushing-----")
print(mse_1985_rushing)
print(r2_1985_rushing)

# 2021 passing MSE and R2
mse_2021_passing = mean_squared_error(qb_2021["Winpct"].values, qb_2021["predicted_Winpct_passing"].values)
r2_2021_passing = r2_score(qb_2021["Winpct"].values, qb_2021["predicted_Winpct_passing"].values)
print("-----2021 Passing-----")
print(mse_2021_passing)
print(r2_2021_passing)

# 2021 rushing MSE and R2
mse_2021_rushing = mean_squared_error(qb_2021["Winpct"].values, qb_2021["predicted_Winpct_rushing"].values)
r2_2021_rushing = r2_score(qb_2021["Winpct"].values, qb_2021["predicted_Winpct_rushing"].values)
print("-----2021 Rushing-----")
print(mse_2021_rushing)
print(r2_2021_rushing)
# Out:
# -----1985 Passing-----
# 0.024013253853953146
# 0.328126193063664
# -----1985 Rushing-----
# 0.028822589491009104
# 0.19356439386078617
# -----2021 Passing-----
# 0.008046242831426303
# 0.6856277114578722
# -----2021 Rushing-----
# 0.016434401623878433
# 0.35789652915517445

# %%
import statsmodels.api as sm

ols_1985_passing = sm.OLS(y_1, sm.add_constant(x_1))
print(ols_1985_passing.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Winpct   R-squared:                       0.328
# Model:                            OLS   Adj. R-squared:                 -0.277
# Method:                 Least Squares   F-statistic:                    0.5426
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):              0.814
# Time:                        22:59:09   Log-Likelihood:                 8.9127
# No. Observations:                  20   AIC:                             2.175
# Df Residuals:                      10   BIC:                             12.13
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -2.3101      2.559     -0.903      0.388      -8.011       3.391
# Age_x         -0.0066      0.020     -0.324      0.753      -0.052       0.039
# Cmp           -0.0024      0.009     -0.258      0.801      -0.023       0.018
# Att_x          0.0037      0.007      0.542      0.599      -0.011       0.019
# Yds_x         -0.0004      0.001     -0.612      0.554      -0.002       0.001
# TD_x          -0.0311      0.032     -0.978      0.351      -0.102       0.040
# Int            0.0447      0.047      0.946      0.366      -0.061       0.150
# Lng_x          0.0006      0.006      0.111      0.914      -0.012       0.013
# Rate           0.0423      0.035      1.195      0.260      -0.037       0.121
# Sk            -0.0031      0.006     -0.538      0.602      -0.016       0.010
# ==============================================================================
# Omnibus:                        2.304   Durbin-Watson:                   2.114
# Prob(Omnibus):                  0.316   Jarque-Bera (JB):                1.306
# Skew:                           0.625   Prob(JB):                        0.521
# Kurtosis:                       3.065   Cond. No.                     1.68e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.68e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
ols_1985_rushing = sm.OLS(y_2, sm.add_constant(x_2))
print(ols_1985_rushing.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Winpct   R-squared:                       0.194
# Model:                            OLS   Adj. R-squared:                 -0.179
# Method:                 Least Squares   F-statistic:                    0.5201
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):              0.783
# Time:                        22:59:09   Log-Likelihood:                 7.0872
# No. Observations:                  20   AIC:                           -0.1744
# Df Residuals:                      13   BIC:                             6.796
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4111      0.626      0.657      0.523      -0.941       1.763
# Age_x          0.0062      0.014      0.440      0.667      -0.024       0.037
# Att_y          0.0003      0.011      0.026      0.980      -0.024       0.024
# Yds_y          0.0008      0.002      0.482      0.638      -0.003       0.004
# TD_y           0.0461      0.059      0.785      0.447      -0.081       0.173
# Lng_y         -0.0069      0.008     -0.819      0.428      -0.025       0.011
# Fmb           -0.0017      0.018     -0.095      0.926      -0.040       0.036
# ==============================================================================
# Omnibus:                        5.972   Durbin-Watson:                   2.248
# Prob(Omnibus):                  0.050   Jarque-Bera (JB):                1.692
# Skew:                           0.118   Prob(JB):                        0.429
# Kurtosis:                       1.595   Cond. No.                     1.62e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.62e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
ols_2021_passing = sm.OLS(y_3, sm.add_constant(x_3))
print(ols_2021_passing.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Winpct   R-squared:                       0.686
# Model:                            OLS   Adj. R-squared:                  0.497
# Method:                 Least Squares   F-statistic:                     3.635
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):             0.0135
# Time:                        22:59:09   Log-Likelihood:                 24.808
# No. Observations:                  25   AIC:                            -29.62
# Df Residuals:                      15   BIC:                            -17.43
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          1.2663      1.303      0.972      0.347      -1.512       4.044
# Age_x          0.0068      0.005      1.272      0.223      -0.005       0.018
# Cmp            0.0069      0.004      1.738      0.103      -0.002       0.015
# Att_x         -0.0056      0.003     -1.773      0.097      -0.012       0.001
# Yds_x        6.12e-05      0.000      0.318      0.755      -0.000       0.000
# TD_x           0.0144      0.010      1.474      0.161      -0.006       0.035
# Int            0.0029      0.017      0.173      0.865      -0.033       0.039
# Lng_x          0.0018      0.003      0.594      0.561      -0.005       0.008
# Rate          -0.0111      0.015     -0.744      0.468      -0.043       0.021
# Sk            -0.0026      0.004     -0.730      0.477      -0.010       0.005
# ==============================================================================
# Omnibus:                        0.739   Durbin-Watson:                   2.233
# Prob(Omnibus):                  0.691   Jarque-Bera (JB):                0.307
# Skew:                          -0.271   Prob(JB):                        0.858
# Kurtosis:                       3.001   Cond. No.                     2.22e+05
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.22e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
ols_2021_rushing = sm.OLS(y_4, sm.add_constant(x_4))
print(ols_2021_rushing.fit().summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 Winpct   R-squared:                       0.358
# Model:                            OLS   Adj. R-squared:                  0.144
# Method:                 Least Squares   F-statistic:                     1.672
# Date:                Wed, 07 Dec 2022   Prob (F-statistic):              0.185
# Time:                        22:59:09   Log-Likelihood:                 15.881
# No. Observations:                  25   AIC:                            -17.76
# Df Residuals:                      18   BIC:                            -9.230
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0038      0.286     -0.013      0.990      -0.605       0.597
# Age_x          0.0137      0.007      2.037      0.057      -0.000       0.028
# Att_y          0.0081      0.005      1.519      0.146      -0.003       0.019
# Yds_y         -0.0011      0.001     -1.282      0.216      -0.003       0.001
# TD_y           0.0103      0.017      0.597      0.558      -0.026       0.046
# Lng_y         -0.0004      0.004     -0.105      0.917      -0.008       0.007
# Fmb           -0.0052      0.010     -0.546      0.592      -0.025       0.015
# ==============================================================================
# Omnibus:                        1.872   Durbin-Watson:                   1.801
# Prob(Omnibus):                  0.392   Jarque-Bera (JB):                0.923
# Skew:                          -0.456   Prob(JB):                        0.630
# Kurtosis:                       3.231   Cond. No.                     2.88e+03
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %%
x_1985 = qb_1985["Player"]
w_1985 = qb_1985["Winpct"]
y_1985 = qb_1985["predicted_Winpct_passing"]
z_1985 = qb_1985["predicted_Winpct_rushing"]

plt.scatter(x_1985, w_1985, color='blue', label='Win %')
plt.scatter(x_1985, y_1985, color='lightblue', label='Expected win % based on passing stats')
plt.scatter(x_1985, z_1985, color='silver', label='Expected win % based on rushing stats')

plt.xlabel("Player")
plt.ylabel("Win %")
plt.title("1985 Quarterbacks' Win % vs. Expected Win %")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(rotation = 90, horizontalalignment='center')
plt.show()

# %%
x_2021 = qb_2021["Player"]
w_2021 = qb_2021["Winpct"]
y_2021 = qb_2021["predicted_Winpct_passing"]
z_2021 = qb_2021["predicted_Winpct_rushing"]

plt.scatter(x_2021, w_2021, color='blue', label='Win %')
plt.scatter(x_2021, y_2021, color='lightblue', label='Expected win % based on passing stats')
plt.scatter(x_2021, z_2021, color='silver', label='Expected win % based on rushing stats')

plt.xlabel("Player")
plt.ylabel("Win %")
plt.title("2021 Quarterbacks' Win % vs. Expected Win %")
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.xticks(rotation = 90, horizontalalignment='center')
plt.show()
